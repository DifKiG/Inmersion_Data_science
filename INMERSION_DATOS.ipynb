# %% [markdown]
# <a href="https://colab.research.google.com/github/DifKiG/Inmersion_Data_science/blob/main/INMERSION_DATOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 1
# ##Primer colab con Python y Pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
inmuebles = pd.read_csv('/content/drive/MyDrive/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %% [markdown]
# El atributo **shape** devuelve la dimension del array. En el caso de inmuebles la tupla que devuelve es; el primer valor = numero de filas y segundo valor = numero de columnas

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# En las siguientes celdas de codigo se crea un diccionario para tratar los nombres de algunas columnas que tienen caracteres especiales y acentos, a su vez se renombra la palabra columnas para que almacene el tratamiento del diccionario, por ultimo se pide una muestra con 10 filas

# %%
columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 6361  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 8047         Casa                       Casa en venta en Suba             6
# 7420  Apartamento                Apartamento en venta en Usme             3
# 5052         Casa              Casa en venta en Santa Barbara             4
# 408   Apartamento         Apartamento en venta en Teusaquillo             1
# 3950  Apartamento            Apartamento en venta en Engativa             3
# 6778         Casa                    Casa en venta en Kennedy             6
# 7922  Apartamento         Apartamento en venta en Teusaquillo             1
# 8400  Apartamento         Apartamento en venta en Chico Norte             3
# 7173  Apartamento      Apartamento en venta en Ciudad Bolívar             3
#
#       Banos  Area              Barrio  \
# 6361      2    91  Zona Noroccidental
# 8047      3   223                Suba
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %% [markdown]
# iloc me trae la fila que le solicito como parametro o un rangoo de filas teniendo en cuenta que el ultimo indice no lo cuenta

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %% [markdown]
# Para traer una columna especifica debo ingresarle el nombre de la variable de la columna y el numero de la fila

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %% [markdown]
# Para saber el tipo de datos tengo lo pido con type

# %%
inmuebles['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %%
type(inmuebles['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Banos', 'Area', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# Para calcular el promedio del area de todos los inmuebles se debe realizar con el dataset.nombreVariables'Area'.mean que se usa para calcular la media de una lista de valores

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# En la siguiente celda se pide una muestra para analizar el promedio o la media de los valores de los inmuebles

# %%
inmuebles.sample(100)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 8320  Apartamento                Apartamento en venta en Suba             3
# 6809         Casa                       Casa en venta en Suba             4
# 436   Apartamento             Apartamento en venta en Kennedy             3
# 2470  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 8976  Apartamento             Apartamento en venta en Usaquén             3
# ...           ...                                         ...           ...
# 2462         Casa               Casa en venta en Los Mártires             5
# 6915         Casa                    Casa en venta en Usaquén             4
# 6980         Casa                    Casa en venta en Kennedy             2
# 5184  Apartamento      Apartamento en venta en Barrios Unidos             2
# 6989         Casa              Casa en venta en Puente Aranda            11
#
#       Banos  Area              Barrio  \
# ...

# %% [markdown]
# Se hace una igualdad para filtrar los barrios que tengan esta media de valor, el resultado es booleno  trayendo un panda series con la afirmacion de esta igualdad

# %%
(inmuebles.Barrio == 'Santa Barbara')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %% [markdown]
# Para obtener el total de cuantos inmuebles cumplen con la igualdad se realiza una suma o mascara cuando sea verdadero suma 1 y cuando es falso suma 0

# %%
sum((inmuebles.Barrio == 'Santa Barbara'))
# Out:
# 438

# %%
inmuebles_santa = (inmuebles.Barrio == 'Santa Barbara')
type(inmuebles_santa)
# Out:
# pandas.core.series.Series

# %%
santa_barbara = inmuebles[inmuebles_santa]
santa_barbara
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 46    Apartamento  Apartamento en venta en Santa Barbara             3      1
# 75    Apartamento  Apartamento en venta en Santa Barbara             3      1
# 99    Apartamento  Apartamento en venta en Santa Barbara             3      3
# 108   Apartamento  Apartamento en venta en Santa Barbara             1      2
# 117   Apartamento  Apartamento en venta en Santa Barbara             2      3
# ...           ...                                    ...           ...    ...
# 9350  Apartamento  Apartamento en venta en Santa Barbara             2      2
# 9356  Apartamento  Apartamento en venta en Santa Barbara             1      1
# 9397  Apartamento  Apartamento en venta en Santa Barbara             3      3
# 9419  Apartamento  Apartamento en venta en Santa Barbara             3      3
# 9441  Apartamento  Apartamento en venta en Santa Barbara             4      5
#
# ...

# %% [markdown]
# Calcular la promedio del area de santa barbara

# %%
santa_barbara.Area.mean()
# Out:
# 124.86986301369863

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# Hallar la cantidad de inmuebles por barrio

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles.UPZ.value_counts()
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %% [markdown]
# funcion para realizar un grafico de cuantos barrios hay en el dataset

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# para sacar el top 10 de los barrios que tienen en ventas en nuestro dataset se usa head(con parametros que necesitamos) y plot.bar para graficar

# %%
inmuebles_barrio.head(10).plot.bar();

# %% [markdown]
# #Desafio 1
# ###Calcular el **promedio** de area de todos los inmuebles en los barrios y hacer grafico top 10

# %%
#mean= promedio, nlargest= valores mas grandes en cada una de las series, groupby= analisa una columna seleccionada para agruparla
inmuebles_area = inmuebles.groupby('Barrio')['Area'].mean().nlargest(10) 
pd.DataFrame(inmuebles_area)
# Out:
#                               Area
# Barrio
# Modelia                4316.750000
# Libertador              642.000000
# Bosa Piamonte           400.000000
# La Soledad              378.625000
# Restrepo                336.500000
# Santa Librada           328.000000
# Las Ferias              320.000000
# Santa Ana               309.375000
# Veraguas                302.666667
# Bellavista Occidental   286.200000

# %% [markdown]
# Se evidencia que en el barrio Modelia tiene el promedio de áreas con mayor tamaño por un error ya que no concuerda el precio con su tamaño de area

# %%
import matplotlib.pyplot as plt
inmuebles_area.head(10).plot.bar(color='yellow');
plt.title('Promedio de area de los barrios');
plt.ylabel('Área');

# %% [markdown]
# #Desafio 2
# ###Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.

# %%
inmuebles.describe()
#conteo,media, estandar de desvio, minima, primer_cuartil, segundo_cuartil, tercer_cuartil, la maxima
# Out:
#        Habitaciones        Banos           Area
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000

# %%
pd.DataFrame(inmuebles.min())
# Out:
# <ipython-input-30-54a3a8ef82ac>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pd.DataFrame(inmuebles.min())
#                                             0
# Tipo                              Apartamento
# Descripcion   Apartamento 27.43 mts DOMUM 141
# Habitaciones                                1
# Banos                                       0
# Area                                        2
# Barrio                                Alameda
# Valor                         $ 1.000.000.000

# %%
pd.DataFrame(inmuebles.max())
# Out:
# <ipython-input-31-e286164c901f>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pd.DataFrame(inmuebles.max())
#                                                               0
# Tipo                                        Oficina/Consultorio
# Descripcion   Oficina/Consultorio en venta en Zona Noroccide...
# Habitaciones                                                110
# Banos                                                         9
# Area                                                     166243
# Barrio                                       Zona Noroccidental
# Valor                                             $ 999.000.000

# %%
pd.DataFrame(inmuebles.median())
# Out:
# <ipython-input-32-e07896659112>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pd.DataFrame(inmuebles.median())
#                  0
# Habitaciones   3.0
# Banos          2.0
# Area          80.0

# %% [markdown]
# #Aula_2
# ##Tratamientos de datos y primeros gráficos

# %%
inmuebles.sample(5)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 3632  Apartamento        Apartamento en venta en Usaquén             2      2
# 2173  Apartamento     Apartamento en venta en La Calleja             3      3
# 1179  Apartamento  Apartamento en venta en Santa Barbara             3      4
# 4394  Apartamento        Apartamento en venta en Usaquén             3      4
# 9493         Casa        Casa en venta en Barrios Unidos             8      6
#
#       Area          Barrio                                    UPZ  \
# 3632    81         Usaquén                                Usaquén
# 2173   110      La Calleja  USAQUÉN: Country Club + Santa Bárbara
# 1179   160   Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 4394   159         Usaquén                                Usaquén
# 9493   247  Barrios Unidos                              Los Andes
#
#                 Valor
# 3632    $ 465.000.000
# 2173    $ 650.000.000
# 1179  $ 1.100.000.000
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# ##analizar el valor de metro cuadrado por barrio
# (valor del inmuble dividirlo con el area)

# %%
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %%
inmuebles.Valor[0].split() #la funcion split() separa una cadena de texto en funcion de algun parametro que le pasemos
# Out:
# ['$', '360.000.000']

# %%
inmuebles.Valor.str.split()  #aplicar split a toda la columna, sigue siendo un panda series pero en formato de lista
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %%
valor = inmuebles.Valor.str.split(expand=True)#al indicar el parametro expand=True me devuelve un DataFrame con dos columnas, sin el parametro devuelve un panda series
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1] 
inmuebles.sample(3)
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8758  Apartamento  Apartamento en venta en Santa Barbara             1      2
# 7619  Apartamento       Apartamento en venta en Engativa             2      1
# 7653         Casa              Casa en venta en Engativa             4      3
#
#       Area         Barrio                                    UPZ  \
# 8758    31  Santa Barbara  USAQUÉN: Country Club + Santa Bárbara
# 7619    70       Engativa                               Engativá
# 7653   109       Engativa                               Engativá
#
#               Valor Moneda       Precio
# 8758  $ 310.000.000      $  310.000.000
# 7619  $ 160.000.000      $  160.000.000
# 7653  $ 540.000.000      $  540.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True) #en esta linea se esta eliminado el punto que esta separando los numeros de la columna valor para convertirlo en float=tipo numerico

# %%
inmuebles[['Precio','Barrio']] # se indica con dos corchetes para que me devuelva un DataFrame
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000 #transformar a tipo de dato numerico a float=valores que puedo tratar con decimales y se divide por un millon para eliminar seis ceros de los valore

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.sample(5) # se evidencia en el DataFrame la columna precio millon con la eliminacion de los 6 ceros
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 8499  Apartamento       Apartamento en venta en Chapinero             2
# 4607  Apartamento  Apartamento en venta en Barrios Unidos             1
# 3255  Apartamento         Apartamento en venta en Usaquén             4
# 8725  Apartamento         Apartamento en venta en Usaquén             3
# 6547  Apartamento        Apartamento en venta en Cedritos             4
#
#       Banos  Area          Barrio                                 UPZ  \
# 8499      3   150       Chapinero  CHAPINERO: Pardo Rubio + Chapinero
# 4607      1    28  Barrios Unidos                           Los Andes
# 3255      5   402         Usaquén                             Usaquén
# 8725      1   210         Usaquén                             Usaquén
# 6547      3    95        Cedritos                             Usaquén
#
#                 Valor Moneda      Precio  Precio_Millon
# ...

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format', lambda x:'%.2f' % x)#funcion lambda permite especificar algo de manera sencillay redondear a dos cifras
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110] #loc me filtra el valor que estoy igualando
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %%
inmuebles['Precio_Millon'].plot.hist(bins=200) #plot de histograma, parametro de bins establezca el rango que abarca el histograma entre mas bins tenga el rango es mas pequeño
# Out:
# <Axes: ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8)) #el 10 es el ancho y el 8 del alto del lienzo

#sns.set_style('dark')

grafica = sns.histplot(data=inmuebles,
                       x='Precio_Millon',
                       kde=True, 
                       hue='Tipo')

grafica.set_title('Distribución de Valores de los inmuebles en Bogota')

plt.xlim((50,1000))

plt.savefig('/content/drive/MyDrive/Gráficos/Histograma1.png' ,
            format='png')
plt.show()

# %% [markdown]
# #Desafio 2 Aula 2
# 1. Estudiar mejor el histograma de valores, seleccionar 3 tipos de inmuebles (Refinar el gráfico: Títulos, aumentar el tamaño de labels, colores, conclusión de la información);
#
# 2. Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.
# 'dividir el precio por metro cuadrado'

# %%
plt.figure(figsize=(10,6)) #el 10 es el ancho y el 6 del alto del lienzo

#sns.set_style('dark')

#sns.set_palette('colorblind')

inmuebles_selec = ((inmuebles.Tipo == 'Bodega') |
                   (inmuebles.Tipo == 'Casa') |
                   (inmuebles.Tipo == 'Apartamento'))

grafica = sns.histplot(data = inmuebles[inmuebles_selec],
                       x='Precio_Millon',
                       kde = True,
                       hue = 'Tipo')

grafica.set_title('Distribucion de Valores de los Apartamentos, Bodegas y Casa del DataFrame',
                  fontsize=14,
                  color='blue')

plt.setp(grafica.get_legend().get_title(),
         fontsize=16)

plt.setp(grafica.get_legend().get_texts(),
         fontsize=14)

plt.xlim((50,1000))

plt.xlabel('Precio_Millon',
           fontsize=16,
           color='Blue')

plt.ylabel('Cantidad de inmuebles',
           fontsize=16,
           color='Blue')

plt.savefig('/content/drive/MyDrive/Gráficos/Histograma.png',
            format='png')

plt.show()

print('En el histograma se evidencia que los apartamentos son los que mas estan a la venta,\n ademas de tener un rango de precios entre los 100 y 190 millones de pesos colombianos,\n las casas estan en un rango de inmuebles que estan en venta y con precios de 100 a 150 millones de pesos,\n por otro lado las bodegas presenta un numero no mayor a 6 inmuebles en venta ')
# Out:
# En el histograma se evidencia que los apartamentos son los que mas estan a la venta,
#  ademas de tener un rango de precios entre los 100 y 190 millones de pesos colombianos,
#  las casas estan en un rango de inmuebles que estan en venta y con precios de 100 a 150 millones de pesos,
#  por otro lado las bodegas presenta un numero no mayor a 6 inmuebles en venta

# %%
inmuebles['Precio_m2'] = inmuebles.Precio_Millon / inmuebles.Area #Creando variable Precio_m2 y dividiendo el precio_millon con area para obtener el valor del m2
inmuebles.head(10)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
# 5  Apartamento         Apartamento en venta en Bella Suiza             1
# 6  Apartamento         Apartamento en venta en Bella Suiza             1
# 7  Apartamento         Apartamento en venta en Bella Suiza             3
# 8  Apartamento            Apartamento en venta en El Chicó             3
# 9  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# ...

# %%
media_m2_precio_barrio = (inmuebles.groupby('Barrio')['Precio_m2']
                          .mean()
                          .reset_index()
                          .sort_values('Precio_m2',
                                       ascending = False))

media_m2_precio_barrio.head(10).plot.bar('Barrio',
                                         'Precio_m2');

# %%
pd.DataFrame(media_m2_precio_barrio.head(10))
# Out:
#               Barrio  Precio_m2
# 49         El Virrey      10.20
# 124        Santa Ana       9.36
# 70         La Merced       8.98
# 28       Chico Norte       8.54
# 86       Los Rosales       8.17
# 45        El Refugio       7.96
# 81        Las Nieves       7.89
# 46         El Retiro       7.72
# 30   Chico Reservado       7.61
# 24         Chapinero       7.43

# %% [markdown]
# #Aula 3
# ##Profundizando el analisis exploratorio

# %% [markdown]
# ##solucion sugerida por el instructor para hallar el Precio del m2 por barrio y hacer el gráfico más adecuado para esta nueva variable.

# %%
inmuebles['Valor_m2_millon'] = inmuebles['Precio_Millon']/inmuebles['Area']
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Precio_m2  \
# 0    $ 360.000.000      $   360000000         360.00       5.14
# 1    $ 670.000.000      $   670000000         670.00       3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00       7.78
#
#    Valor_m2_millon
# 0             5.14
# 1             3.94
# 2             7.78

# %%
#Para todas las columnas numericas trae el promedio con la funcion groupby y mean
inmuebles.groupby('Barrio').mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_Millon  Precio_m2  \
# Barrio
# Alameda                     3.00   2.00  97.00         580.00       5.98
# Alhambra                    3.00   2.94 190.41         752.35       4.33
# Andes Norte                 3.00   2.86 124.86         709.57       6.05
# Antonio Nariño              4.31   2.50 163.06         459.22       3.53
# Barrancas                   2.87   2.13  70.20         314.13       4.42
# ...                          ...    ...    ...            ...        ...
# Villa Maria                 4.69   3.69 207.15         402.85       2.04
# Villas De Granada           3.45   2.32  86.59         282.30       3.17
# Villemar                    2.94   2.06  76.89         303.83       3.99
# Zona Franca                 2.00   1.00  54.00         160.00       2.96
# Zona Noroccidental          3.17   2.51 135.79         620.81       4.62
#
#                     Valor_m2_millon
# Barrio
# Alameda                        5.98
# ...

# %%
#calcular valor especifico del m2 por barrio 
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  Precio_m2  \
# Barrio
# Alameda                        3      2      97         580.00       5.98
# Alhambra                      51     50    3237       12790.00      73.56
# Andes Norte                   21     20     874        4967.00      42.35
# Antonio Nariño               207    120    7827       22042.65     169.47
# Barrancas                     43     32    1053        4712.00      66.24
# ...                          ...    ...     ...            ...        ...
# Villa Maria                   61     48    2693        5237.00      26.58
# Villas De Granada             76     51    1905        6210.62      69.71
# Villemar                      53     37    1384        5469.00      71.81
# Zona Franca                    2      1      54         160.00       2.96
# Zona Noroccidental          2778   2204  119084      544453.06    4049.16
#
#                     Valor_m2_millon
# Barrio
# ...

# %%
datos_barrio['Precio_m2'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  Precio_m2  \
# Barrio
# Alameda                        3      2      97         580.00       5.98
# Alhambra                      51     50    3237       12790.00       3.95
# Andes Norte                   21     20     874        4967.00       5.68
# Antonio Nariño               207    120    7827       22042.65       2.82
# Barrancas                     43     32    1053        4712.00       4.47
# ...                          ...    ...     ...            ...        ...
# Villa Maria                   61     48    2693        5237.00       1.94
# Villas De Granada             76     51    1905        6210.62       3.26
# Villemar                      53     37    1384        5469.00       3.95
# Zona Franca                    2      1      54         160.00       2.96
# Zona Noroccidental          2778   2204  119084      544453.06       4.57
#
#                     Valor_m2_millon
# Barrio
# ...

# %%
#creacion de diccionario 
m2_barrio = dict(datos_barrio['Precio_m2'])

# %%
inmuebles['Precio_m2'] = inmuebles['Barrio']
inmuebles['Precio_m2'] = inmuebles['Precio_m2'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Precio_m2  \
# ...

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index

# %%
datos_barrio.reset_index(inplace=True)# datos_barrio es un dataset creado para darle mejor tratamiento a los datos 
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Precio_m2  Valor_m2_millon
# 0         5.98             5.98
# 1         3.95            73.56
# 2         5.68            42.35
# ...

# %%
datos_barrio.query('Barrio in @top_barrios') #la @ hace referencia a la variable top_barrios para que me devuelva el array que contiene los indices
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Precio_m2  Valor_m2_millon
# 5         2.96          2070.61
# 10        2.68          1654.36
# 22        5.03          2853.23
# 24        4.58          2466.03
# 50        2.89          1795.71
# ...

# %%
plt.figure(figsize=(10,8))
ax =sns.barplot(x='Barrio',
                y='Precio_m2',
                data = datos_barrio
                .query('Barrio in @top_barrios'))
ax.tick_params(axis='x',
               rotation = 45)

# %%
plt.figure(figsize=(10,8))

ax =sns.boxplot(x='Barrio',
                y='Valor_m2_millon',
                data =inmuebles
                .query('Barrio in @top_barrios'))

ax.tick_params(axis='x',
               rotation = 45)
plt.show()

# %%
plt.figure(figsize=(10,8))

ax =sns.boxplot(x='Barrio',
                y='Valor_m2_millon',
                data =inmuebles
                .query('Barrio in @top_barrios & Valor_m2_millon < 15'))

ax.tick_params(axis='x',
               rotation = 45)
plt.show()

# %%
plt.figure(figsize=(10,8))

ax =sns.boxplot(x='Barrio',
                y='Area',
                data = inmuebles
                .query('Barrio in @top_barrios & Area < 500'))

ax.tick_params(axis='x',
               rotation = 45)
plt.show()

# %% [markdown]
# Vamos a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE y vamos a ver como estos datos nos ayudarían en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de Bogotá.
#
# Encuesta Multiproposito de Bogotá para obtener información socio-económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
# https://microdatos.dane.gov.co/index.php/catalog/743

# %%
datos_a = pd.read_csv('/content/drive/MyDrive/archivos-dane/Identificación (Capítulo A).csv',
                        sep = ';',
                        encoding = 'latin-1')
datos_a.head(15)
# Out:
#     DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0   3004346.00    11  11001      1           3.00         Santa Fe
# 1   3004347.00    11  11001      1          14.00     Los Mártires
# 2   3004348.00    11  11001      1           3.00         Santa Fe
# 3   3004349.00    11  11001      1           1.00          Usaquén
# 4   3004350.00    11  11001      1           1.00          Usaquén
# 5   3004351.00    11  11001      1           2.00        Chapinero
# 6   3004352.00    11  11001      1           2.00        Chapinero
# 7   3004353.00    11  11001      1           9.00         Fontibón
# 8   3004354.00    11  11001      1           9.00         Fontibón
# 9   3004355.00    11  11001      1           1.00          Usaquén
# 10  3004356.00    11  11001      1           1.00          Usaquén
# 11  3004357.00    11  11001      1           1.00          Usaquén
# 12  3004358.00    11  11001      1           2.00        Chapinero
# ...

# %%
datos_a.shape
# Out:
# (106467, 11)

# %%
datos_a = datos_a.loc[datos_a.MPIO == 11001]
datos_a.shape
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/archivos-dane/Datos de la vivenda y su entorno (Capítulo B).csv',
                        sep = ';',
                        encoding = 'latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv',
                        sep = ';',
                        encoding = 'latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/archivos-dane/Composición del hogar y demografía (Capítulo E).csv',
                        sep = ';',
                        encoding = 'latin-1')

datos_h = pd.read_csv('/content/drive/MyDrive/archivos-dane/Educación (Capítulo H).csv',
                        sep = ';',
                        encoding = 'latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/archivos-dane/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv',
                        sep = ';',
                        encoding = 'latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/archivos-dane/Fuerza de trabajo (Capítulo K).csv',
                        sep = ';',
                        encoding = 'latin-1')
# Out:
# <ipython-input-73-fd040aa0071c>:4: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv',
# <ipython-input-73-fd040aa0071c>:7: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/archivos-dane/Composición del hogar y demografía (Capítulo E).csv',
# <ipython-input-73-fd040aa0071c>:11: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/archivos-dane/Educación (Capítulo H).csv',
# <ipython-input-73-fd040aa0071c>:14: DtypeWarning: Columns (114,117,122,126,164,166,168) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
#merge hace una funcion de tablas
#se crea una nueva tabla que contenga el resto de tablas en una sola
datos_dane = pd.merge(datos_a,
                      datos_b,
                      on = 'DIRECTORIO',
                      how = 'left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,
                      datos_c,
                      on = 'DIRECTORIO',
                      how = 'left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane,
                      datos_e,
                      on = 'DIRECTORIO',
                      how = 'left')
datos_dane.shape
# Out:
# <ipython-input-76-8e3befd982e7>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# #Desafíos de esta aula
# 1. Dar un vistazo a la base de datos del DANE, comprender conceptualmente estas variables para entender mejor el contexto de esta base de datos
#
# 2. Organizar tu notebook para que tu proyecto quede mejor presentado.

# %% [markdown]
# #Aula 4
# ###Cruzando bases y Machine Learning

# %%
datos_dane = pd.read_csv('/content/drive/MyDrive/archivos-dane/datos_dane.csv')

# %%
datos_dane.head()
# Out:
#    DIRECTORIO NOMBRE_LOCALIDAD                                 NOMBRE_ESTRATO  \
# 0  3004368.00          Usaquén  USAQUÉN: Paseo de Los Libertadores + La Uribe
# 1  3004369.00          Usaquén                                        Usaquén
# 2  3004375.00        Chapinero             CHAPINERO: Pardo Rubio + Chapinero
# 3  3004380.00          Usaquén                                     Los Cedros
# 4  3004383.00         Fontibón                      Ciudad Salitre Occidental
#
#    NVCBP4  NVCBP14A  NVCBP14D  NVCBP14E  NVCBP14G  NVCBP15A  NVCBP15C  ...  \
# 0       1         2         2         2         2         2         2  ...
# 1       1         2         2         2         2         2         2  ...
# 2       2         2         2         2         2         2         1  ...
# 3       1         2         2         2         2         2         2  ...
# 4       1         2         2         2         2         1         2  ...
#
# ...

# %%
datos_dane.shape
# Out:
# (9857, 55)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   DIRECTORIO        9857 non-null   float64
#  1   NOMBRE_LOCALIDAD  9857 non-null   object
#  2   NOMBRE_ESTRATO    9857 non-null   object
#  3   NVCBP4            9857 non-null   int64
#  4   NVCBP14A          9857 non-null   int64
#  5   NVCBP14D          9857 non-null   int64
#  6   NVCBP14E          9857 non-null   int64
#  7   NVCBP14G          9857 non-null   int64
#  8   NVCBP15A          9857 non-null   int64
#  9   NVCBP15C          9857 non-null   int64
#  10  NVCBP15F          9857 non-null   int64
#  11  NVCBP15G          9857 non-null   int64
#  12  NVCBP16A3         9857 non-null   int64
#  13  NVCBP16A4         9857 non-null   int64
#  14  NPCKP17           9857 non-null   float64
#  15  NPCKP18           9857 non-null   float64
# ...

# %%
dic_dane = {
       'NVCBP4':'CONJUNTO_CERRADO',
       'NVCBP14A':'FABRICAS_CERCA', 'NVCBP14D':'TERMINALES_BUS', 'NVCBP14E':'BARES_DISCO', 
       'NVCBP14G':'OSCURO_PELIGROSO', 'NVCBP15A':'RUIDO', 'NVCBP15C':'INSEGURIDAD',
       'NVCBP15F':'BASURA_INADECUADA', 'NVCBP15G':'INVASION','NVCBP16A3':'MOV_ADULTOS_MAYORES', 
       'NVCBP16A4':'MOV_NINOS_BEBES',
       'NPCKP17':'OCUPACION','NPCKP18':'CONTRATO','NPCKP23':'SALARIO_MES', 
       'NPCKP44A':'DONDE_TRABAJA', 'NPCKPN62A':'DECLARACION_RENTA', 
       'NPCKPN62B':'VALOR_DECLARACION', 'NPCKP64A':'PERDIDA_TRABAJO_C19', 
       'NPCKP64E':'PERDIDA_INGRESOS_C19',
       'NHCCP3':'TIENE_ESCRITURA', 'NHCCP6':'ANO_COMPRA', 'NHCCP7':'VALOR_COMPRA', 'NHCCP8_1':'HIPOTECA_CRED_BANCO',
       'NHCCP8_2':'OTRO_CRED_BANCO', 'NHCCP8_3':'CRED_FNA', 'NHCCP8_6':'PRESTAMOS_AMIGOS',
       'NHCCP8_7':'CESANTIAS', 'NHCCP8_8':'AHORROS', 'NHCCP8_9':'SUBSIDIOS',
       'NHCCP9':'CUANTO_PAGARIA_MENSUAL', 'NHCCP11':'PLANES_ADQUIRIR_VIVIENDA', 
       'NHCCP11A':'MOTIVO_COMPRA', 'NHCCP12':'RAZON_NO_ADQ_VIV', 'NHCCP41':'TIENE_CARRO','NHCCP41A':'CUANTOS_CARROS',
       'NHCCP47A':'TIENE_PERROS', 'NHCCP47B':'TIENE_GATOS', 'NHCLP2A':'VICTIMA_ATRACO', 'NHCLP2B':'VICTIMA_HOMICIDIO', 
       'NHCLP2C':'VICTIMA_PERSECUSION',
       'NHCLP2E':'VICTIMA_ACOSO', 'NHCLP4':'COMO_VIVE_ECON', 'NHCLP5':'COMO_NIVEL_VIDA', 
       'NHCLP8AB':'REACCION_OPORTUNA_POLICIA', 'NHCLP8AE':'COMO_TRANSPORTE_URBANO', 'NHCLP10':'SON_INGRESOS_SUFICIENTES',
       'NHCLP11':'SE_CONSIDERA_POBRE', 'NHCLP29_1A':'MED_C19_TRABAJO', 
       'NHCLP29_1C':'MED_C19_CAMBIO_VIVIENDA', 'NHCLP29_1E':'MED_C19_ENDEUDAMIENTO', 
       'NHCLP29_1F':'MED_C19_VENTA_BIENES','NPCHP4':'NIVEL_EDUCATIVO'
       }

datos_dane = datos_dane.rename(columns=dic_dane)
datos_dane.columns
# Out:
# Index(['DIRECTORIO', 'NOMBRE_LOCALIDAD', 'NOMBRE_ESTRATO', 'CONJUNTO_CERRADO',
#        'FABRICAS_CERCA', 'TERMINALES_BUS', 'BARES_DISCO', 'OSCURO_PELIGROSO',
#        'RUIDO', 'INSEGURIDAD', 'BASURA_INADECUADA', 'INVASION',
#        'MOV_ADULTOS_MAYORES', 'MOV_NINOS_BEBES', 'OCUPACION', 'CONTRATO',
#        'SALARIO_MES', 'DONDE_TRABAJA', 'DECLARACION_RENTA',
#        'VALOR_DECLARACION', 'PERDIDA_TRABAJO_C19', 'PERDIDA_INGRESOS_C19',
#        'TIENE_ESCRITURA', 'ANO_COMPRA', 'VALOR_COMPRA', 'HIPOTECA_CRED_BANCO',
#        'OTRO_CRED_BANCO', 'CRED_FNA', 'PRESTAMOS_AMIGOS', 'CESANTIAS',
#        'AHORROS', 'SUBSIDIOS', 'CUANTO_PAGARIA_MENSUAL',
#        'PLANES_ADQUIRIR_VIVIENDA', 'MOTIVO_COMPRA', 'RAZON_NO_ADQ_VIV',
#        'TIENE_CARRO', 'CUANTOS_CARROS', 'TIENE_PERROS', 'TIENE_GATOS',
#        'VICTIMA_ATRACO', 'VICTIMA_HOMICIDIO', 'VICTIMA_PERSECUSION',
#        'VICTIMA_ACOSO', 'COMO_VIVE_ECON', 'COMO_NIVEL_VIDA',
#        'REACCION_OPORTUNA_POLICIA', 'COMO_TRANSPORTE_URBANO',
# ...

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9857 entries, 0 to 9856
# Data columns (total 55 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DIRECTORIO                 9857 non-null   float64
#  1   NOMBRE_LOCALIDAD           9857 non-null   object
#  2   NOMBRE_ESTRATO             9857 non-null   object
#  3   CONJUNTO_CERRADO           9857 non-null   int64
#  4   FABRICAS_CERCA             9857 non-null   int64
#  5   TERMINALES_BUS             9857 non-null   int64
#  6   BARES_DISCO                9857 non-null   int64
#  7   OSCURO_PELIGROSO           9857 non-null   int64
#  8   RUIDO                      9857 non-null   int64
#  9   INSEGURIDAD                9857 non-null   int64
#  10  BASURA_INADECUADA          9857 non-null   int64
#  11  INVASION                   9857 non-null   int64
#  12  MOV_ADULTOS_MAYORES        9857 non-null   int64
# ...

# %%
datos_dane.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean().head()
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   1.89
# Américas                                                      1.38
# Apogeo                                                        1.65
# Arborizadora                                                  1.43
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              1.37
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# 20 de Julio                                              1.19            1.85
# Américas                                                 1.25            1.98
# Apogeo                                                   1.30            1.75
# Arborizadora                                             1.30            1.95
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre         1.33            1.99
#
# ...

# %%
#se realiza por medio del reaplece el cambio de las respuestas de la encuesta que dicen 'NO=2' a 'NO=0'
datos = datos_dane[['NOMBRE_ESTRATO','CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].replace(2,0)
datos
# Out:
#                                      NOMBRE_ESTRATO  CONJUNTO_CERRADO  \
# 0     USAQUÉN: Paseo de Los Libertadores + La Uribe                 1
# 1                                           Usaquén                 1
# 2                CHAPINERO: Pardo Rubio + Chapinero                 0
# 3                                        Los Cedros                 1
# 4                         Ciudad Salitre Occidental                 1
# ...                                             ...               ...
# 9852         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9853         SANTA FE: Las Nieves + Sagrado Corazón                 0
# 9854         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9855         SANTA FE: Las Nieves + Sagrado Corazón                 1
# 9856                                   Santa Isabel                 0
#
#       INSEGURIDAD  TERMINALES_BUS  BARES_DISCO  RUIDO  OSCURO_PELIGROSO  \
# ...

# %%
datos.NOMBRE_ESTRATO.value_counts() # se realiza un value_counts() para saber si no se afecto 'NOMBRE_ESTRATO' en el cambio de 'NO=2' a 'NO=0'
# Out:
# Niza                                                   243
# SUBA: La Academia + Guaymaral + San José de Bavaria    212
# CHAPINERO: Chicó Lago + El Refugio                     210
# Los Libertadores                                       208
# Modelia                                                205
#                                                       ...
# Tunjuelito                                              26
# Lourdes                                                 25
# Localidad Chapinero resto                               21
# Localidad Usaquén resto                                 10
# Localidad Santa Fe resto                                 8
# Name: NOMBRE_ESTRATO, Length: 102, dtype: int64

# %%
datos.loc[datos.NOMBRE_ESTRATO == '20 de Julio']
# Out:
#      NOMBRE_ESTRATO  CONJUNTO_CERRADO  INSEGURIDAD  TERMINALES_BUS  \
# 513     20 de Julio                 0            0               0
# 706     20 de Julio                 0            1               0
# 707     20 de Julio                 0            1               0
# 708     20 de Julio                 0            1               0
# 709     20 de Julio                 0            1               0
# ...             ...               ...          ...             ...
# 8372    20 de Julio                 0            1               0
# 8751    20 de Julio                 0            0               0
# 8752    20 de Julio                 0            1               0
# 8783    20 de Julio                 0            1               1
# 9287    20 de Julio                 0            1               0
#
#       BARES_DISCO  RUIDO  OSCURO_PELIGROSO  SALARIO_MES  TIENE_ESCRITURA  \
# 513             0      1                 0        98.00             1.00
# ...

# %%
datos_tratados = datos.groupby('NOMBRE_ESTRATO')[['CONJUNTO_CERRADO','INSEGURIDAD','TERMINALES_BUS','BARES_DISCO','RUIDO','OSCURO_PELIGROSO','SALARIO_MES','TIENE_ESCRITURA','PERDIDA_TRABAJO_C19','PERDIDA_INGRESOS_C19','PLANES_ADQUIRIR_VIVIENDA']].mean()
datos_tratados
# Out:
#                                                   CONJUNTO_CERRADO  \
# NOMBRE_ESTRATO
# 20 de Julio                                                   0.11
# Américas                                                      0.62
# Apogeo                                                        0.35
# Arborizadora                                                  0.57
# BARRIOS UNIDOS: Parque Salitre + Doce de Octubre              0.63
# ...                                                            ...
# Usaquén                                                       0.90
# Venecia                                                       0.47
# Verbenal                                                      0.77
# Zona Franca                                                   0.94
# Álamos                                                        0.65
#
#                                                   INSEGURIDAD  TERMINALES_BUS  \
# NOMBRE_ESTRATO
# ...

# %%
pd.merge(inmuebles,datos_tratados, 
         left_on = 'UPZ',
         right_on = 'NOMBRE_ESTRATO',
         how = 'left')
# Out:
#              Tipo                                     Descripcion  \
# 0     Apartamento      Apartamento en venta en Zona Noroccidental
# 1            Casa                       Casa en venta en Castilla
# 2     Apartamento         Apartamento en venta en Chico Reservado
# 3     Apartamento                 Apartamento en venta en Usaquén
# 4     Apartamento             Apartamento en venta en Bella Suiza
# ...           ...                                             ...
# 9515  Apartamento                 Apartamento en venta en Kennedy
# 9516  Apartamento  Apartamento en venta en Parque Central Bavaria
# 9517        Local                      Local en venta en Restrepo
# 9518         Casa                       Casa en venta en Engativa
# 9519  Apartamento                 Apartamento en venta en Tintala
#
#       Habitaciones  Banos  Area                  Barrio  \
# 0                3      2    70      Zona Noroccidental
# 1                4      3   170                Castilla
# ...

# %%
datos_ml = pd.merge(inmuebles,datos_tratados, 
         left_on = 'UPZ',
         right_on = 'NOMBRE_ESTRATO',
         how = 'left')
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9520 entries, 0 to 9519
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9520 non-null   object
#  1   Descripcion               9520 non-null   object
#  2   Habitaciones              9520 non-null   int64
#  3   Banos                     9520 non-null   int64
#  4   Area                      9520 non-null   int64
#  5   Barrio                    9520 non-null   object
#  6   UPZ                       9478 non-null   object
#  7   Valor                     9520 non-null   object
#  8   Moneda                    9520 non-null   object
#  9   Precio                    9520 non-null   object
#  10  Precio_Millon             9520 non-null   float64
#  11  Precio_m2                 9520 non-null   float64
#  12  Valor_m2_millon           9520 non-null   float64
# ...

# %%
#el DataFrame de la izquierda va a ser datos_ml y los de la derecha va ser UPZ esto se hace por que los
# dos DataFrame tienen columnas que se llaman UPZ y NOMBRE_ESTRATO que refieren a lo mismo
# con el inner join se hace la intercepcion de las dos tablas que tiene correspondencia en el DataFrame de inmuebles y datos_dane
#para continuar trabajando con el modelo de machine learning ademas de que necesitamos que el 
#campo sea numerico para aplicar el modelo de regresion 
upz = pd.read_csv('/content/drive/MyDrive/archivos-dane/cod_upz.csv')
datos_ml = pd.merge(datos_ml,upz,left_on='UPZ',right_on='NOMBRE_ESTRATO', how='inner')
datos_ml.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                      Casa en venta en Marly             3
# 2         Casa         Casa en venta en Zona Noroccidental             3
# 3  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 4         Casa         Casa en venta en Zona Noroccidental             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   147               Marly  CHAPINERO: Pardo Rubio + Chapinero
# 2      4   300  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 3      1    45  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 4      6   380  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#              Valor Moneda      Precio  ...  BARES_DISCO  RUIDO  \
# ...

# %%
datos_ml.shape
# Out:
# (9318, 26)

# %%
datos_ml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9318 entries, 0 to 9317
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Tipo                      9318 non-null   object
#  1   Descripcion               9318 non-null   object
#  2   Habitaciones              9318 non-null   int64
#  3   Banos                     9318 non-null   int64
#  4   Area                      9318 non-null   int64
#  5   Barrio                    9318 non-null   object
#  6   UPZ                       9318 non-null   object
#  7   Valor                     9318 non-null   object
#  8   Moneda                    9318 non-null   object
#  9   Precio                    9318 non-null   object
#  10  Precio_Millon             9318 non-null   float64
#  11  Precio_m2                 9318 non-null   float64
#  12  Valor_m2_millon           9318 non-null   float64
# ...

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml,
            y='Precio_Millon')
plt.show()

# %%
datos_ml.query('Precio_Millon > 5000 | Precio_Millon < 60')
# Out:
#                      Tipo                                  Descripcion  \
# 207           Apartamento            Apartamento en venta en Chapinero
# 323                 Local                  Local en venta en Chapinero
# 702                  Casa                   Casa en venta en Chapinero
# 708                  Casa                   Casa en venta en Chapinero
# 829           Apartamento   Apartamento en venta en Zona Noroccidental
# 1371          Apartamento             Apartamento en venta en El Chicó
# 1414          Apartamento             Apartamento en venta en El Chicó
# 1429                Local             Local en venta en Quinta Camacho
# 1442                Local             Local en venta en Quinta Camacho
# 1518          Apartamento      Apartamento en venta en Chico Reservado
# 1532          Apartamento          Apartamento en venta en Chico Norte
# 1533          Apartamento          Apartamento en venta en Los Rosales
# ...

# %%
datos_ml = datos_ml.query('Precio_Millon < 1200 & Precio_Millon > 60')
datos_ml
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 0     Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1            Casa                      Casa en venta en Marly             3
# 3     Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9            Casa         Casa en venta en Zona Noroccidental             5
# 10    Apartamento  Apartamento en venta en Zona Noroccidental             3
# ...           ...                                         ...           ...
# 9313  Apartamento            Apartamento en venta en Verbenal             2
# 9314  Apartamento            Apartamento en venta en Verbenal             2
# 9315  Apartamento            Apartamento en venta en Verbenal             2
# 9316  Apartamento            Apartamento en venta en Verbenal             2
# 9317  Apartamento            Apartamento en venta en Verbenal             2
#
# ...

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=datos_ml,
            y='Precio_Millon')
plt.show()

# %%
datos_ml['SALARIO_ANUAL_MI'] = datos_ml['SALARIO_MES']*12/1000000
datos_ml['SALARIO_ANUAL_MI']
# Out:
# 0      48.42
# 1      48.42
# 3      48.42
# 9      48.42
# 10     48.42
#         ...
# 9313   29.34
# 9314   29.34
# 9315   29.34
# 9316   29.34
# 9317   29.34
# Name: SALARIO_ANUAL_MI, Length: 8313, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=datos_ml,
            x='SALARIO_ANUAL_MI',
            y='Valor_m2_millon')
plt.ylim((0,15))
plt.show()

# %%
# se convinan las variables entre ellas para ver como se correlaciona
#entre mas cercano a 1 quiere decir que se relacionan o es la misma, 
#si el valor es cercano a 1 quiere decir que hay una correlacion directa
#si el valor va a -1 quiere decir que hay una correlacion indirecta es inverso
# el 0 no tiene relacion 
#cuando una variable crece la otra crece= directamente corrlacionada
#cuando una crece la otra decrece estan inversamente correlacionada
datos_ml.corr()
# Out:
#                           Habitaciones  Banos  Area  Precio_Millon  Precio_m2  \
# Habitaciones                      1.00   0.44  0.03           0.18      -0.21
# Banos                             0.44   1.00  0.04           0.66       0.13
# Area                              0.03   0.04  1.00           0.04      -0.04
# Precio_Millon                     0.18   0.66  0.04           1.00       0.40
# Precio_m2                        -0.21   0.13 -0.04           0.40       1.00
# Valor_m2_millon                  -0.31  -0.03 -0.04           0.36       0.49
# CONJUNTO_CERRADO                 -0.12   0.16 -0.01           0.32       0.65
# INSEGURIDAD                       0.13  -0.19 -0.00          -0.37      -0.66
# TERMINALES_BUS                    0.08  -0.17 -0.01          -0.28      -0.38
# BARES_DISCO                       0.11  -0.12 -0.01          -0.23      -0.41
# RUIDO                             0.14  -0.17 -0.00          -0.35      -0.66
# ...

# %%
plt.figure(figsize=(18, 8))
#https://www.tylervigen.com/spurious-correlations
#mascara = np.triu(np.ones_like(datos_ml.corr(), dtype=bool)) mask=mascara,
heatmap = sns.heatmap(datos_ml.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlación de las variables', fontdict={'fontsize':18}, pad=16);

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = datos_ml[['COD_UPZ_GRUPO']]
y = datos_ml['Precio_Millon']

X_train, X_test, y_train, y_test =train_test_split(X,y,test_size=0.25,random_state=99)

# %%
X_train
# Out:
#       COD_UPZ_GRUPO
# 1512         817.00
# 7864          85.00
# 6058          21.00
# 1683         817.00
# 2481          14.00
# ...             ...
# 6038          21.00
# 8875         102.00
# 2200          14.00
# 3883         803.00
# 8154          85.00
#
# [6234 rows x 1 columns]

# %%
X_test
# Out:
#       COD_UPZ_GRUPO
# 6340          74.00
# 7805          85.00
# 4902          47.00
# 7041         100.00
# 2436          14.00
# ...             ...
# 3323          14.00
# 3945         803.00
# 5572          27.00
# 3633         803.00
# 3652         803.00
#
# [2079 rows x 1 columns]

# %%
y_test
# Out:
# 6340   199.90
# 7805   120.80
# 4902   400.00
# 7041   340.00
# 2436   355.00
#         ...
# 3323   700.00
# 3945   510.00
# 5572   220.00
# 3633   420.00
# 3652   435.60
# Name: Precio_Millon, Length: 2079, dtype: float64

# %%
y_train
# Out:
# 1512   1050.00
# 7864    129.00
# 6058    206.38
# 1683    650.00
# 2481    250.00
#          ...
# 6038    560.00
# 8875    560.00
# 2200    685.00
# 3883    850.00
# 8154    132.00
# Name: Precio_Millon, Length: 6234, dtype: float64

# %%
modelo= LinearRegression()

# %%
modelo.fit(X_train,y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
y_predict_test= modelo.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

baseline_mae = mean_absolute_error(y_test, y_predict_test)
baseline_r2 = r2_score(y_test, y_predict_test)
baseline_r2
# Out:
# 0.031111799984413713

# %%
X = datos_ml[['COD_UPZ_GRUPO','Habitaciones','Banos','CONJUNTO_CERRADO','SALARIO_ANUAL_MI','TIENE_ESCRITURA']] #,

Y = datos_ml["Precio_Millon"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 99)
modelo_1 = LinearRegression()
modelo_1.fit(X_train, y_train)
y_predict_test = modelo_1.predict(X_test)
y_predict_train = modelo_1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict_test)
r2_test = r2_score(y_test, y_predict_test)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train, y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 118.25967274431333 0.5404735562069192
# 123.22271988681676 0.5269614226488988

# %%
modelo_1.predict([[816,3,2,1,50,1]])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([434.21129691])

# %% [markdown]
# #Desafio
# Probar con otros modelos de ML;
#
# Trabajar más con los datos y crear nuevas variables;
#
# Probar predicciones para casos reales;
#
# Crear un proyecto con los resultados de la inmersión y publicarlo en las redes sociales mostrando el trabajo realizado. Recuerda etiquetar a @aluralatam y utilizar los hashtags #InmersionDatos e #InmersionDatosAluraLatam.
